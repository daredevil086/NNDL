# %% [markdown]
#       14(b) Build a text preprocessing pipeline using torchtext or nltk for Amazon Food Reviews.

# %% [markdown]
# https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews
# DOwnload unzip and upload

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78833e0b-f59e-40ad-8cf4-2c7ef676fd78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78833e0b-f59e-40ad-8cf4-2c7ef676fd78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install NLTK
# !pip install nltk

# Imports
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Load dataset
df = pd.read_csv("Reviews.csv")

# Preview key columns
df = df[['Id', 'UserId', 'ProductId', 'ProfileName', 'Score', 'Time', 'Summary', 'Text']]
df.dropna(subset=["Text"], inplace=True)
df.head()
# Out:
#    Id          UserId   ProductId                      ProfileName  Score  \
# 0   1  A3SGXH7AUHU8GW  B001E4KFG0                       delmartian      5
# 1   2  A1D87F6ZCVE5NK  B00813GRG4                           dll pa      1
# 2   3   ABXLMWJIXXAIN  B000LQOCH0  Natalia Corres "Natalia Corres"      4
# 3   4  A395BORC6FGVXV  B000UA0QIQ                             Karl      2
# 4   5  A1UQRSCLF8GW1T  B006K2ZZ7K    Michael D. Bigham "M. Wassir"      5
#
#          Time                Summary  \
# 0  1303862400  Good Quality Dog Food
# 1  1346976000      Not as Advertised
# 2  1219017600  "Delight" says it all
# 3  1307923200         Cough Medicine
# 4  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# ...

# %%
# Initialize NLTK tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # Lowercase and tokenize
    tokens = word_tokenize(text.lower())

    # Remove stopwords and non-alphabetic tokens
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

    # Lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return tokens

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Use a smaller subset for demo purposes (1000 reviews)
sample_df = df.head(1000).copy()

# Apply preprocessing
sample_df['Processed'] = sample_df['Text'].apply(preprocess_text)

# Show results
sample_df[['Text', 'Processed']].head()
# Out:
#                                                 Text  \
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...
#
#                                            Processed
# 0  [bought, several, vitality, canned, dog, food,...
# 1  [product, arrived, labeled, jumbo, salted, pea...
# 2  [confection, around, century, light, pillowy, ...
# 3  [looking, secret, ingredient, robitussin, beli...
# 4  [great, taffy, great, price, wide, assortment,...
