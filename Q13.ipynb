# %% [markdown]
# ### 13.(a) Compare binary and multi-class classification problems.

# %% [raw]
# Binary vs Multi-Class Classification
#
# Number of Classes:
# Binary: 2 classes (e.g., 0 or 1).
# Multi-Class: More than 2 classes (e.g., 3 or more).
#
# Output Layer:
# Binary: 1 or 2 output neurons.
# Multi-Class: 1 output neuron per class.
#
# Activation Function:
# Binary: Sigmoid (outputs probability for 1 class).
# Multi-Class: Softmax (outputs probabilities for multiple classes).
#
# Loss Function:
# Binary: Binary Cross-Entropy.
# Multi-Class: Categorical Cross-Entropy.
#
# Model Output:
# Binary: Predicts either class 0 or 1.
# Multi-Class: Predicts one of the several possible classes.
#
# Evaluation Metrics:
# Binary: Accuracy, Precision, Recall, F1 Score (for 2 classes).
# Multi-Class: Accuracy, Precision, Recall, F1 Score (averaged across multiple classes).
#
# Decision Threshold:
# Binary: Typically 0.5 to separate classes.
# Multi-Class: The highest probability class is chosen.
#
# Training Complexity:
# Binary: Less complex as only 2 classes need to be differentiated.
# Multi-Class: More complex due to handling multiple classes.
#
# Confusion Matrix:
# Binary: 2x2 matrix (True Positive, True Negative, False Positive, False Negative).
# Multi-Class: NxN matrix (for N classes).
#
# Classification Example:
# Binary: Classifying whether an email is spam or not.
# Multi-Class: Classifying a photo as cat, dog, or bird.

# %% [markdown]
# ###  13(b) Implement a confusion matrix and classification report for any dataset.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm)
# Classification Report

cr=classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
